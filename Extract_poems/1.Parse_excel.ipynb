# %% [markdown]
# # Parse excel from norn collaborators

# %%
import pandas as pd
import numpy as np
import re
from typing import List, Iterable, Tuple, NamedTuple, TypedDict

from norn.poems import Poem, PoemCollection, create_list_of_books, PoemsTester
from norn.utils import is_valid_digibok_urn

# %%
# Import Ranveig's data
data1 = "pabegynt_1880_dikt__sidetall.xlsx"
data2 = "1890 enkeltdikt.xlsx"
data = data2


df = pd.read_excel(data, header=None)

# %%
df
# Out:
#                                         0                      1  \
# 0                         1890 enkeltdikt                    NaN
# 1     URN:NBN:no-nb_digibok_2009032303011      Andersen, Tryggve
# 2                                     NaN         Tittel på dikt
# 3                                     NaN              Variation
# 4                                     NaN  Pigen med fuglefælden
# ...                                   ...                    ...
# 3222                                  NaN              I kvelden
# 3223                                  NaN           Ljose netter
# 3224                                  NaN          17de mai 1892
# 3225                                  NaN               Matpoesi
# 3226                                  NaN                 Farvel
#
#                    2               3         4                        5  \
# 0                NaN             NaN       NaN                      NaN
# 1              Digte            1898       NaN                      NaN
# 2     Sidetall START  Sidetall SLUTT  Overlapp  Mangler digital visning
# 3                  8               9       NaN                      NaN
# 4                 10              12       NaN                      NaN
# ...              ...             ...       ...                      ...
# 3222              91              92         x                      NaN
# 3223              92              93         x                      NaN
# 3224              93              95         x                      NaN
# 3225              95              96         x                      NaN
# 3226              96              97         x                      NaN
#
#                               6
# 0                           NaN
# 1                           NaN
# 2                   Kommentarer
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3222                        NaN
# 3223                        NaN
# 3224                        NaN
# 3225                        NaN
# 3226  Mel: Vort land, vort land
#
# [3227 rows x 7 columns]

# %%
poems = create_list_of_books(df) # Create a list of poems using the parser script
poems[:2]
# Out:
# [Poem(urn='URN:NBN:no-nb_digibok_2009032303011', title='Variation', page_start=8, page_end=9, overlapp=nan, digital_visning=nan, comment=nan, dhlabid=None, pages=None),
#  Poem(urn='URN:NBN:no-nb_digibok_2009032303011', title='Pigen med fuglefælden', page_start=10, page_end=12, overlapp=nan, digital_visning=nan, comment=nan, dhlabid=None, pages=None)]

# %%
df = pd.DataFrame(poems)

# %%
df.loc[df.page_start.apply(lambda x: isinstance(x, str))] # Find the poems that have a page number not int
# Out:
#                                       urn      title page_start  page_end  \
# 2592  URN:NBN:no-nb_digibok_2009032303010  Ein Grust    droppe        NaN
#
#      overlapp digital_visning   comment dhlabid pages
# 2592      NaN             NaN  På tysk!    None  None

# %%
PoemsTester(poems) # Test poems
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 PoemsTester(poems) # Test poems
#
# File ~/projects/NORN/norn/poems.py:87, in PoemsTester.__init__(self, poems)
#      84 self.poems = poems
#      86 assert self.test_urn(), "URN not valid"
# ---> 87 assert self.test_page_start(), "Page start not valid"
#      88 assert self.test_page_end(), "Page end not valid"
#      90 print("All tests passed")
#
# AssertionError: Page start not valid

# %%
df.loc[df.urn.apply(is_valid_digibok_urn)] # Check if the urns are valid
# Out:
#                                       urn                    title page_start  \
# 0     URN:NBN:no-nb_digibok_2009032303011                Variation          8
# 1     URN:NBN:no-nb_digibok_2009032303011    Pigen med fuglefælden         10
# 2     URN:NBN:no-nb_digibok_2009032303011              Troldsøstre         13
# 3     URN:NBN:no-nb_digibok_2009032303011             I Sarons dal         15
# 4     URN:NBN:no-nb_digibok_2009032303011                     Idyl         17
# ...                                   ...                      ...        ...
# 2936  URN:NBN:no-nb_digibok_2010081610001          Et elskovsdrama         17
# 2937  URN:NBN:no-nb_digibok_2010081610001  Eneboerens livshistorie         18
# 2938  URN:NBN:no-nb_digibok_2010081610001       Forkröblet kludder         22
# 2939  URN:NBN:no-nb_digibok_2010081610001                 For sent         33
# 2940  URN:NBN:no-nb_digibok_2010081610001                 Hr. Mads         34
#
#       page_end overlapp digital_visning                    comment dhlabid  \
# 0          9.0      NaN             NaN                        NaN     NaN
# 1         12.0      NaN             NaN                        NaN     NaN
# 2         14.0      NaN             NaN                        NaN     NaN
# 3         16.0      NaN             NaN                        NaN     NaN
# 4         18.0      NaN             NaN                        NaN     NaN
# ...        ...      ...             ...                        ...     ...
# 2936      18.0        x             NaN                        NaN    None
# 2937      21.0        x             NaN                Del I til V    None
# 2938      32.0      NaN             NaN  Replikker, dramatisk dikt    None
# 2939      33.0      NaN             NaN                        NaN    None
# 2940      34.0      NaN             NaN                        NaN    None
#
#      pages
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2936  None
# 2937  None
# 2938  None
# 2939  None
# 2940  None
#
# [2941 rows x 9 columns]

# %% [markdown]
# ## Remove error

# %%
df.dtypes # Check the data types
# Out:
# urn                 object
# title               object
# page_start          object
# page_end           float64
# overlapp            object
# digital_visning     object
# comment             object
# dhlabid             object
# pages               object
# dtype: object

# %%
df.loc[df["page_end"].isna()] # Check for NaN values in page_end
# Out:
#                                       urn      title page_start  page_end  \
# 2592  URN:NBN:no-nb_digibok_2009032303010  Ein Grust    droppe        NaN
#
#      overlapp digital_visning   comment dhlabid pages
# 2592      NaN             NaN  På tysk!    None  None

# %%
df = df.loc[df["page_end"].notna()] # Drop NaN values in page_end

# %%
df['page_end'] = df['page_end'].astype(int) # Convert page_end to int

# %%
df.loc[df["page_end"].apply(lambda x: not isinstance(x, int))] # Check for non-int values in page_end
# Out:
# Empty DataFrame
# Columns: [urn, title, page_start, page_end, overlapp, digital_visning, comment, dhlabid, pages]
# Index: []

# %%
poems = [Poem(*x) for x in df.values] # Create a list of poems from the df

# %%
PoemsTester(poems) # Test the poems
# Out:
# All tests passed

# %% [markdown]
# ## Assign an ID to each row
#
# each norn poem should have a dhlab id
#
# dhlab_norn_00001

# %%
def assing_dhlabid(poems: List[Poem]) -> List[Poem]:
    """Assign a dhlabid to each poem"""
    template = "dhlab_norn_poem_{:05}"
    
    for i, poem in enumerate(poems):
        poem.dhlabid = template.format(i + 1)
    return poems

# %%
assing_dhlabid(poems)

PoemsTester(poems)

df = pd.DataFrame(poems)
df
# Out:
# All tests passed
#                                       urn                    title  \
# 0     URN:NBN:no-nb_digibok_2009032303011                Variation
# 1     URN:NBN:no-nb_digibok_2009032303011    Pigen med fuglefælden
# 2     URN:NBN:no-nb_digibok_2009032303011              Troldsøstre
# 3     URN:NBN:no-nb_digibok_2009032303011             I Sarons dal
# 4     URN:NBN:no-nb_digibok_2009032303011                     Idyl
# ...                                   ...                      ...
# 2935  URN:NBN:no-nb_digibok_2010081610001          Et elskovsdrama
# 2936  URN:NBN:no-nb_digibok_2010081610001  Eneboerens livshistorie
# 2937  URN:NBN:no-nb_digibok_2010081610001       Forkröblet kludder
# 2938  URN:NBN:no-nb_digibok_2010081610001                 For sent
# 2939  URN:NBN:no-nb_digibok_2010081610001                 Hr. Mads
#
#       page_start  page_end overlapp digital_visning  \
# 0              8         9      NaN             NaN
# 1             10        12      NaN             NaN
# 2             13        14      NaN             NaN
# 3             15        16      NaN             NaN
# 4             17        18      NaN             NaN
# ...          ...       ...      ...             ...
# 2935          17        18        x             NaN
# 2936          18        21        x             NaN
# 2937          22        32      NaN             NaN
# 2938          33        33      NaN             NaN
# 2939          34        34      NaN             NaN
#
#                         comment                dhlabid pages
# 0                           NaN  dhlab_norn_poem_00001  None
# 1                           NaN  dhlab_norn_poem_00002  None
# 2                           NaN  dhlab_norn_poem_00003  None
# 3                           NaN  dhlab_norn_poem_00004  None
# 4                           NaN  dhlab_norn_poem_00005  None
# ...                         ...                    ...   ...
# 2935                        NaN  dhlab_norn_poem_02936  None
# 2936                Del I til V  dhlab_norn_poem_02937  None
# 2937  Replikker, dramatisk dikt  dhlab_norn_poem_02938  None
# 2938                        NaN  dhlab_norn_poem_02939  None
# 2939                        NaN  dhlab_norn_poem_02940  None
#
# [2940 rows x 9 columns]

# %% [markdown]
# ## Export

# %%
df.to_csv("poems.csv", index=False)

# %% [markdown]
# File page  https://api.nb.no/catalog/v1/metadata/URN:NBN:no-nb_digibok_2014110308039/altos/URN:NBN:no-nb_digibok_2014110308039_C1
#
# https://api.nb.no/catalog/v1/metadata/URN:NBN:no-nb_digibok_2014110308039/altos/URN:NBN:no-nb_digibok_2014110308039_I1
